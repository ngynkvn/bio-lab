# %%
# %%time
# f = open('test_ecoli', 'r')
f = open('omsim_ecoli_05_015', 'r')
# f = ['Rmap_193 21.767 12.118 28.965 29.134 3.428 26.367 7.788 10.751 15.66 11.687 11.022 8.103 3.946 35.932 2.591 18.609 17.574 2.205 13.081 9.96 3.421 11.298 1.395 3.519 2.483 22.925 2.687 16.295 2.797 3.712 8.736 2.663 7.352 25.61 28.897 5.243',
# 'Rmap_101 2.678 8.033 4.023 35.631 2.575 18.453 17.487 2.212 12.969 9.922 3.456 11.132 1.354 3.84 2.547 16.551 3.189 2.562 1.922 1.579 15.074 3.25 3.41 8.794 10.152 4.285 20.87 22.134 6.591 12.18 1.542']
data = {}
n = 0
for line in f:
    line = line.split(' ')
    data[line[0]] = list(map(float, line[1:]))
    if n == 500:
#         pass
        break
    n += 1
print(len(data.keys()), "Rmaps,",sum(map(len, data.values())), "Fragments.")
# f.close()
# Out:
# 501 Rmaps, 14018 Fragments.
# Wall time: 66.6 ms

# %%
# %%time
def kmers(li, k=5):
    return [tuple(li[i:i+k]) for i in range(len(li) - k + 1)]
kmap = {}
rmap = {}
kmer_list = []
for k, v in data.items():
    kmrs = kmers(v)
    rmap[k] = kmrs
    kmer_list.extend(kmrs)
    kmap.update(zip(kmrs, [k]*len(kmrs)))
print(len(kmer_list), "Kmers")
# Out:
# 12014 Kmers
# Wall time: 33 ms

# %%
# %%time
from sklearn.cluster import DBSCAN
from sklearn.neighbors import KDTree
import numpy as np
import sklearn
import itertools
from operator import itemgetter
from collections import defaultdict
from pprint import pprint
alpha = 5 #
clusters = defaultdict(set)
clusters_with_kmer = defaultdict(set)

clustering = DBSCAN(eps=.5, min_samples = 2).fit_predict(kmer_list)
for kmer, label in zip(kmer_list, clustering):
    if label != -1:
        clusters[label].add((kmap[kmer], kmer))
rmap_relations = defaultdict(int)

for s in clusters.values():
    for i_j in itertools.combinations(map(itemgetter(0), s), 2):
        rmap_relations[i_j] += 1
pprint(sorted(filter(lambda x: x[1] >= alpha, rmap_relations.items()), key=itemgetter(1), reverse=True))
# Out:
# [(('Rmap_394', 'Rmap_279'), 11),
#  (('Rmap_443', 'Rmap_167'), 10),
#  (('Rmap_347', 'Rmap_87'), 10),
#  (('Rmap_72', 'Rmap_337'), 9),
#  (('Rmap_160', 'Rmap_87'), 9),
#  (('Rmap_109', 'Rmap_87'), 9),
#  (('Rmap_271', 'Rmap_346'), 9),
#  (('Rmap_296', 'Rmap_375'), 8),
#  (('Rmap_298', 'Rmap_0'), 8),
#  (('Rmap_161', 'Rmap_245'), 8),
#  (('Rmap_178', 'Rmap_407'), 8),
#  (('Rmap_338', 'Rmap_334'), 8),
#  (('Rmap_15', 'Rmap_140'), 8),
#  (('Rmap_244', 'Rmap_316'), 8),
#  (('Rmap_87', 'Rmap_347'), 8),
#  (('Rmap_310', 'Rmap_312'), 8),
#  (('Rmap_127', 'Rmap_236'), 8),
#  (('Rmap_127', 'Rmap_157'), 8),
#  (('Rmap_157', 'Rmap_229'), 8),
#  (('Rmap_432', 'Rmap_79'), 8),
#  (('Rmap_270', 'Rmap_467'), 8),
#  (('Rmap_0', 'Rmap_433'), 7),
#  (('Rmap_137', 'Rmap_253'), 6),
#  (('Rmap_296', 'Rmap_308'), 6),
#  (('Rmap_308', 'Rmap_411'), 6),
#  (('Rmap_0', 'Rmap_296'), 5),
#  (('Rmap_0', 'Rmap_40'), 5),
#  (('Rmap_232', 'Rmap_296'), 5),
#  (('Rmap_296', 'Rmap_274'), 5),
#  (('Rmap_296', 'Rmap_40'), 5),
#  (('Rmap_298', 'Rmap_40'), 5),
#  (('Rmap_0', 'Rmap_222'), 5),
#  (('Rmap_449', 'Rmap_433'), 5),
#  (('Rmap_222', 'Rmap_449'), 5),
#  (('Rmap_298', 'Rmap_449'), 5),
#  (('Rmap_70', 'Rmap_50'), 5),
#  (('Rmap_398', 'Rmap_49'), 5),
#  (('Rmap_3', 'Rmap_176'), 5),
#  (('Rmap_176', 'Rmap_228'), 5),
#  (('Rmap_12', 'Rmap_214'), 5),
#  (('Rmap_253', 'Rmap_299'), 5),
#  (('Rmap_144', 'Rmap_460'), 5),
#  (('Rmap_178', 'Rmap_161'), 5),
#  (('Rmap_178', 'Rmap_8'), 5),
#  (('Rmap_178', 'Rmap_164'), 5),
#  (('Rmap_178', 'Rmap_233'), 5),
#  (('Rmap_164', 'Rmap_245'), 5),
#  (('Rmap_139', 'Rmap_178'), 5),
#  (('Rmap_403', 'Rmap_114'), 5),
#  (('Rmap_131', 'Rmap_11'), 5),
#  (('Rmap_11', 'Rmap_115'), 5),
#  (('Rmap_131', 'Rmap_181'), 5),
#  (('Rmap_25', 'Rmap_181'), 5),
#  (('Rmap_131', 'Rmap_25'), 5),
#  (('Rmap_83', 'Rmap_115'), 5),
#  (('Rmap_115', 'Rmap_293'), 5),
#  (('Rmap_217', 'Rmap_348'), 5),
#  (('Rmap_227', 'Rmap_26'), 5),
#  (('Rmap_26', 'Rmap_14'), 5),
#  (('Rmap_337', 'Rmap_14'), 5),
#  (('Rmap_337', 'Rmap_459'), 5),
#  (('Rmap_337', 'Rmap_27'), 5),
#  (('Rmap_448', 'Rmap_171'), 5),
#  (('Rmap_378', 'Rmap_15'), 5),
#  (('Rmap_15', 'Rmap_374'), 5),
#  (('Rmap_15', 'Rmap_243'), 5),
#  (('Rmap_15', 'Rmap_370'), 5),
#  (('Rmap_94', 'Rmap_15'), 5),
#  (('Rmap_395', 'Rmap_243'), 5),
#  (('Rmap_167', 'Rmap_261'), 5),
#  (('Rmap_167', 'Rmap_279'), 5),
#  (('Rmap_443', 'Rmap_261'), 5),
#  (('Rmap_443', 'Rmap_279'), 5),
#  (('Rmap_394', 'Rmap_28'), 5),
#  (('Rmap_352', 'Rmap_279'), 5),
#  (('Rmap_242', 'Rmap_28'), 5),
#  (('Rmap_168', 'Rmap_360'), 5),
#  (('Rmap_26', 'Rmap_252'), 5),
#  (('Rmap_72', 'Rmap_294'), 5),
#  (('Rmap_294', 'Rmap_337'), 5),
#  (('Rmap_294', 'Rmap_234'), 5),
#  (('Rmap_29', 'Rmap_59'), 5),
#  (('Rmap_476', 'Rmap_289'), 5),
#  (('Rmap_429', 'Rmap_474'), 5),
#  (('Rmap_429', 'Rmap_255'), 5),
#  (('Rmap_264', 'Rmap_373'), 5),
#  (('Rmap_123', 'Rmap_440'), 5),
#  (('Rmap_317', 'Rmap_160'), 5),
#  (('Rmap_222', 'Rmap_375'), 5),
#  (('Rmap_41', 'Rmap_101'), 5),
#  (('Rmap_41', 'Rmap_193'), 5),
#  (('Rmap_91', 'Rmap_201'), 5),
#  (('Rmap_484', 'Rmap_256'), 5),
#  (('Rmap_191', 'Rmap_160'), 5),
#  (('Rmap_191', 'Rmap_347'), 5),
#  (('Rmap_483', 'Rmap_197'), 5),
#  (('Rmap_367', 'Rmap_398'), 5),
#  (('Rmap_367', 'Rmap_58'), 5),
#  (('Rmap_58', 'Rmap_398'), 5),
#  (('Rmap_398', 'Rmap_367'), 5),
#  (('Rmap_283', 'Rmap_50'), 5),
#  (('Rmap_452', 'Rmap_312'), 5),
#  (('Rmap_208', 'Rmap_100'), 5),
#  (('Rmap_236', 'Rmap_482'), 5),
#  (('Rmap_57', 'Rmap_178'), 5),
#  (('Rmap_242', 'Rmap_68'), 5),
#  (('Rmap_242', 'Rmap_469'), 5),
#  (('Rmap_68', 'Rmap_469'), 5),
#  (('Rmap_173', 'Rmap_451'), 5),
#  (('Rmap_187', 'Rmap_451'), 5),
#  (('Rmap_319', 'Rmap_79'), 5),
#  (('Rmap_151', 'Rmap_205'), 5),
#  (('Rmap_307', 'Rmap_105'), 5),
#  (('Rmap_87', 'Rmap_109'), 5),
#  (('Rmap_483', 'Rmap_87'), 5),
#  (('Rmap_122', 'Rmap_201'), 5),
#  (('Rmap_259', 'Rmap_271'), 5),
#  (('Rmap_271', 'Rmap_259'), 5),
#  (('Rmap_494', 'Rmap_418'), 5),
#  (('Rmap_309', 'Rmap_395'), 5),
#  (('Rmap_208', 'Rmap_389'), 5),
#  (('Rmap_157', 'Rmap_389'), 5),
#  (('Rmap_114', 'Rmap_338'), 5),
#  (('Rmap_253', 'Rmap_334'), 5),
#  (('Rmap_433', 'Rmap_149'), 5),
#  (('Rmap_149', 'Rmap_298'), 5),
#  (('Rmap_391', 'Rmap_467'), 5),
#  (('Rmap_230', 'Rmap_395'), 5),
#  (('Rmap_235', 'Rmap_315'), 5)]
# Wall time: 372 ms

# %%
'''
Random code here.
'''
# kd = KDTree(np.array(kmer_list))
# results = kd.query_radius(kmer_list, .5)
# clusts = set(frozenset(map(lambda x: kmer_list[x], r)) for r in results if len(r) > 1)
# clusts = set(frozenset(map(lambda x: kmap[kmer_list[x]], r)) for r in results if len(r) > 1)
# clusts = set(frozenset(r) for r in results if len(r) > 1)
# print(len(clusts))
# rmap_relations = defaultdict(int)
# for s in clusts:
#     for i_j in itertools.combinations(s, 2):
#         rmap_relations[i_j] += 1
# pprint(rmap_relations)
# pprint()
# print(clusters)
# clust2 = set(frozenset(k) for k in clusters.values())
# f = open('yeet.txt', 'w')
# f2 = open('yeet2.txt', 'w')
# f3 = open('y3.txt', 'w')
# f.write(pformat(clusts))
# f2.write(pformat(clust2))
# f3.write(pformat(clusts ^ clust2))
# f.close()
# f2.close()
# f3.close()
# print(sklearn.metrics.silhouette_score(kmer_list, clustering, metric='euclidean'))
